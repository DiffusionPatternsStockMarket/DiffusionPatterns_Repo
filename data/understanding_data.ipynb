# %%
import andi
from andi import andi_datasets
import numpy as np
from matplotlib import pyplot as plt
import random

# %% [markdown]
# $\{0:"attm",1:"ctrw",2:"fbm",3:"lw",4:"sbm"\}$
#
# $LW: \alpha > 1.0$
#
# $ATTM \space and \space CTRW: \alpha <= 1.0$

# %%
AD = andi_datasets()
a,b = random.randint(50,600),random.randint(50,600)
lw = AD.create_dataset(T=a,N=1,exponents=[1.01,1.3,1.5],models=[3],dimension=1,save_trajectories=True,path="./datasets/")
fmb = AD.create_dataset(T=b,N=1,exponents=[1],models=[2],dimension=1,save_trajectories=True,path="./datasets/")
ctrw = AD.create_dataset(T=b,N=1,exponents=[0.75],models=[1],dimension=1,save_trajectories=True,path="./datasets/")
# Out:
# The dataset for lw with exponent 1.01 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:11<00:00, 87.42it/s, exponent=1.3, model=lw, saving=1]
# The dataset for lw with exponent 1.5 already exists, no need of saving it again.
# The dataset for fbm with exponent 1 already exists, no need of saving it again.
# The dataset for ctrw with exponent 0.75 already exists, no need of saving it again.

# %%
data = np.concatenate((ctrw[0,2:],fmb[0,2:]))

# %%
plt.plot([i for i in range(fmb.shape[1]+ctrw.shape[1]-4)],data)
plt.ylabel("x");plt.xlabel("t");

# %% [markdown]
# ### Comparación dentro de un mismo tipo de movimiento pero con distintos $\alpha$

# %% [markdown]
# ##### CTRW

# %%
t1,t2,t3,t4 = (random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400))
exp1,exp2,exp3,exp4 = (random.randint(0,100)/100),(random.randint(0,100)/100),(random.randint(0,100)/100),(random.randint(0,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[1],dimension=1,save_trajectories=True,path="./datasets/");
walk3 = AD.create_dataset(T=t3,N=1,exponents=[exp3],models=[1],dimension=1,save_trajectories=True,path="./datasets/");
walk4 = AD.create_dataset(T=t4,N=1,exponents=[exp4],models=[1],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# ...
# 100%|██████████| 1000/1000 [00:00<00:00, 6588.24it/s, exponent=0.77, model=ctrw, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:],walk3[0,2:],walk4[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r");plt.axvline(t1+t2,color="r");plt.axvline(t1+t2+t3,color="r");
plt.text(t1//2,min(data),f"{exp1}");plt.text(t1 + (t2//2),min(data),f"{exp2}");plt.text(t1+t2+(t3//2),min(data),f"{exp3}");plt.text(t1+t2+t3+(t4//2),min(data),f"{exp4}");

# %% [markdown]
# ##### ATTM

# %%
t1,t2,t3,t4 = (random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400))
exp1,exp2,exp3,exp4 = (random.randint(0,25)/100),(random.randint(26,50)/100),(random.randint(51,75)/100),(random.randint(76,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[0],dimension=1,save_trajectories=True,path="./datasets/");
walk3 = AD.create_dataset(T=t3,N=1,exponents=[exp3],models=[0],dimension=1,save_trajectories=True,path="./datasets/");
walk4 = AD.create_dataset(T=t4,N=1,exponents=[exp4],models=[0],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.05 already exists, no need of saving it again.
# The dataset for attm with exponent 0.37 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 1931.32it/s, exponent=0.59, model=attm, saving=1]
# The dataset for attm with exponent 0.82 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:],walk3[0,2:],walk4[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r");plt.axvline(t1+t2,color="r");plt.axvline(t1+t2+t3,color="r");
plt.text(t1//2,min(data),f"{exp1}");plt.text(t1 + (t2//2),min(data),f"{exp2}");plt.text(t1+t2+(t3//2),min(data),f"{exp3}");plt.text(t1+t2+t3+(t4//2),min(data),f"{exp4}");

# %% [markdown]
# ##### FBM

# %%
t1,t2,t3,t4 = (random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400))
exp1,exp2,exp3,exp4 = (random.randint(0,45)/100),(random.randint(46,90)/100),(random.randint(91,135)/100),(random.randint(136,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[2],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
walk3 = AD.create_dataset(T=t3,N=1,exponents=[exp3],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
walk4 = AD.create_dataset(T=t4,N=1,exponents=[exp4],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# ...
# 100%|██████████| 1000/1000 [00:16<00:00, 61.89it/s, exponent=1.51, model=fbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:],walk3[0,2:],walk4[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r");plt.axvline(t1+t2,color="r");plt.axvline(t1+t2+t3,color="r");
plt.text(t1//2,min(data),f"{exp1}");plt.text(t1 + (t2//2),min(data),f"{exp2}");plt.text(t1+t2+(t3//2),min(data),f"{exp3}");plt.text(t1+t2+t3+(t4//2),min(data),f"{exp4}");

# %% [markdown]
# ##### LW

# %%
t1,t2,t3,t4 = (random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400))
exp1,exp2,exp3,exp4 = (random.randint(100,125)/100),(random.randint(126,150)/100),(random.randint(151,175)/100),(random.randint(176,200)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[3],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
walk3 = AD.create_dataset(T=t3,N=1,exponents=[exp3],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
walk4 = AD.create_dataset(T=t4,N=1,exponents=[exp4],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# ...
# 100%|██████████| 1000/1000 [00:07<00:00, 142.76it/s, exponent=1.42, model=lw, saving=1]
# The dataset for lw with exponent 1.62 already exists, no need of saving it again.
# The dataset for lw with exponent 1.91 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:],walk3[0,2:],walk4[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r");plt.axvline(t1+t2,color="r");plt.axvline(t1+t2+t3,color="r");
plt.text(t1//2,min(data),f"{exp1}");plt.text(t1 + (t2//2),min(data),f"{exp2}");plt.text(t1+t2+(t3//2),min(data),f"{exp3}");plt.text(t1+t2+t3+(t4//2),min(data),f"{exp4}");

# %% [markdown]
# ##### SBM

# %%
t1,t2,t3,t4 = (random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400)),(random.randint(100,400))
exp1,exp2,exp3,exp4 = (random.randint(0,45)/100),(random.randint(46,90)/100),(random.randint(91,135)/100),(random.randint(136,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[4],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
walk3 = AD.create_dataset(T=t3,N=1,exponents=[exp3],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
walk4 = AD.create_dataset(T=t4,N=1,exponents=[exp4],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for sbm with exponent 0.41 already exists, no need of saving it again.
# The dataset for sbm with exponent 0.75 already exists, no need of saving it again.
# The dataset for sbm with exponent 1.03 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 7881.73it/s, exponent=1.63, model=sbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:],walk3[0,2:],walk4[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r");plt.axvline(t1+t2,color="r");plt.axvline(t1+t2+t3,color="r");
plt.text(t1//2,min(data),f"{exp1}");plt.text(t1 + (t2//2),min(data),f"{exp2}");plt.text(t1+t2+(t3//2),min(data),f"{exp3}");plt.text(t1+t2+t3+(t4//2),min(data),f"{exp4}");

# %% [markdown]
# ### Comparación entre distintos modelos con mismo $\alpha$

# %% [markdown]
# $\{0:"attm",1:"ctrw",2:"fbm",3:"lw",4:"sbm"\}$
#
# $LW: \alpha > 1.0$
#
# $ATTM \space and \space CTRW: \alpha <= 1.0$

# %% [markdown]
# #### ATTM & CTRW

# %% [markdown]
# ###### Con un exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(50,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[1],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.85 already exists, no need of saving it again.
# The dataset for ctrw with exponent 0.85 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"attm");plt.text(t1 + (t2//2),min(data),"ctrw");

# %% [markdown]
# ###### Con un exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(0,50)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[1],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 5624.58it/s, exponent=0.19, model=attm, saving=1]
# The dataset for ctrw with exponent 0.19 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"attm");plt.text(t1 + (t2//2),min(data),"ctrw");

# %% [markdown]
# ##### ATTM & FBM

# %% [markdown]
# ###### Con un exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(50,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.86 already exists, no need of saving it again.
# The dataset for fbm with exponent 0.86 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"attm");plt.text(t1 + (t2//2),min(data),"fbm");

# %% [markdown]
# ###### Con un exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(0,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.59 already exists, no need of saving it again.
# The dataset for fbm with exponent 0.59 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"attm");plt.text(t1 + (t2//2),min(data),"fbm");

# %% [markdown]
# ##### ATTM & SBM

# %% [markdown]
# ###### Con un exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(75,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.78 already exists, no need of saving it again.
# The dataset for sbm with exponent 0.78 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"attm");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ###### Con un exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(0,20)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.18 already exists, no need of saving it again.
# The dataset for sbm with exponent 0.18 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"attm");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ##### CTRW & FBM

# %% [markdown]
# ###### Con exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(50,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for ctrw with exponent 0.91 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:17<00:00, 57.47it/s, exponent=0.91, model=fbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"ctrw");plt.text(t1 + (t2//2),min(data),"fbm");

# %% [markdown]
# ###### Con exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(0,50)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for ctrw with exponent 0.15 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:16<00:00, 61.33it/s, exponent=0.15, model=fbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"ctrw");plt.text(t1 + (t2//2),min(data),"fbm");

# %% [markdown]
# ##### CTRW & SBM

# %% [markdown]
# ###### Con exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(50,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for ctrw with exponent 0.82 already exists, no need of saving it again.
# The dataset for sbm with exponent 0.82 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"ctrw");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ###### Con exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(0,50)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for ctrw with exponent 0.15 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 8803.92it/s, exponent=0.15, model=sbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"ctrw");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ##### FBM & LW

# %% [markdown]
# ###### Con exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(151,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# ...
# 100%|██████████| 1000/1000 [00:05<00:00, 186.08it/s, exponent=1.55, model=lw, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"fbm");plt.text(t1 + (t2//2),min(data),"lw");

# %% [markdown]
# ###### Con exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(100,150)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# 100%|██████████| 1000/1000 [00:16<00:00, 59.44it/s, exponent=1.2, model=fbm, saving=1]
# The dataset for lw with exponent 1.2 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"fbm");plt.text(t1 + (t2//2),min(data),"lw");

# %% [markdown]
# ##### FBM & SBM

# %% [markdown]
# ###### Con exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(100,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# 100%|██████████| 1000/1000 [00:17<00:00, 58.35it/s, exponent=1.67, model=fbm, saving=1]
# The dataset for sbm with exponent 1.67 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"fbm");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ###### Con exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(0,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[2],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# 100%|██████████| 1000/1000 [00:16<00:00, 61.89it/s, exponent=0.35, model=fbm, saving=1]
# The dataset for sbm with exponent 0.35 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"fbm");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ##### LW & SBM

# %% [markdown]
# ###### Con exponente alto

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(150,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[3],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# 100%|██████████| 1000/1000 [00:04<00:00, 222.56it/s, exponent=1.7, model=lw, saving=1]
# The dataset for sbm with exponent 1.7 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"lw");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ###### Con exponente bajo

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp = (random.randint(101,150)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp],models=[3],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for lw with exponent 1.25 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 8867.58it/s, exponent=1.25, model=sbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),"lw");plt.text(t1 + (t2//2),min(data),"sbm");

# %% [markdown]
# ### Comparación entre distintos modelos con distinto $\alpha$

# %% [markdown]
# $\{0:"attm",1:"ctrw",2:"fbm",3:"lw",4:"sbm"\}$
#
# $LW: \alpha > 1.0$
#
# $ATTM \space and \space CTRW: \alpha <= 1.0$

# %% [markdown]
# ##### ATTM & CTRW

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,100)/100),(random.randint(0,100)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[1],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.75 already exists, no need of saving it again.
# The dataset for ctrw with exponent 0.32 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"attm,{exp1}");plt.text(t1 + (t2//2),min(data),f"ctrw,{exp2}");

# %% [markdown]
# ##### ATTM & FBM

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,100)/100),(random.randint(0,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.15 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:17<00:00, 58.01it/s, exponent=0.78, model=fbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"attm,{exp1}");plt.text(t1 + (t2//2),min(data),f"fbm,{exp2}");

# %% [markdown]
# ##### ATTM & LW

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,100)/100),(random.randint(101,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.56 already exists, no need of saving it again.
# The dataset for lw with exponent 1.59 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"attm,{exp1}");plt.text(t1 + (t2//2),min(data),f"lw,{exp2}");

# %% [markdown]
# ##### ATTM & SBM

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,100)/100),(random.randint(0,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[0],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for attm with exponent 0.05 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 8341.58it/s, exponent=1.21, model=sbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"attm,{exp1}");plt.text(t1 + (t2//2),min(data),f"sbm,{exp2}");

# %% [markdown]
# ##### CTRW & FBM

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,100)/100),(random.randint(0,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[2],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for ctrw with exponent 0.71 already exists, no need of saving it again.
# The dataset for fbm with exponent 1.72 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"ctrw,{exp1}");plt.text(t1 + (t2//2),min(data),f"fbm,{exp2}");

# %% [markdown]
# ##### CTRW & LW

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,100)/100),(random.randint(101,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 10391.56it/s, exponent=0.22, model=ctrw, saving=1]
# The dataset for lw with exponent 1.67 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"ctrw,{exp1}");plt.text(t1 + (t2//2),min(data),f"lw,{exp2}");

# %% [markdown]
# ##### CTRW & SBM

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,100)/100),(random.randint(0,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[1],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for ctrw with exponent 0.93 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 7960.34it/s, exponent=1.74, model=sbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"ctrw,{exp1}");plt.text(t1 + (t2//2),min(data),f"sbm,{exp2}");

# %% [markdown]
# ##### FBM & LW

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,180)/100),(random.randint(101,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[2],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[3],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# 100%|██████████| 1000/1000 [00:16<00:00, 61.93it/s, exponent=0.69, model=fbm, saving=1]
# The dataset for lw with exponent 1.67 already exists, no need of saving it again.

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"fbm,{exp1}");plt.text(t1 + (t2//2),min(data),f"lw,{exp2}");

# %% [markdown]
# ##### FBM & SBM

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(0,180)/100),(random.randint(0,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[2],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for fbm with exponent 1.05 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 8343.30it/s, exponent=0.24, model=sbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"fbm,{exp1}");plt.text(t1 + (t2//2),min(data),f"sbm,{exp2}");

# %% [markdown]
# ##### LW & SBM

# %%
t1,t2 = (random.randint(100,600)),(random.randint(100,600))
exp1,exp2 = (random.randint(101,180)/100),(random.randint(0,180)/100)
walk1 = AD.create_dataset(T=t1,N=1,exponents=[exp1],models=[3],dimension=1,save_trajectories=True,path="./datasets/"); 
walk2 = AD.create_dataset(T=t2,N=1,exponents=[exp2],models=[4],dimension=1,save_trajectories=True,path="./datasets/");
# Out:
# The dataset for lw with exponent 1.72 already exists, no need of saving it again.
# 100%|██████████| 1000/1000 [00:00<00:00, 6730.86it/s, exponent=1.48, model=sbm, saving=1]

# %%
data = np.concatenate((walk1[0,2:],walk2[0,2:]))
plt.plot([i for i in range(data.shape[0])],data)
plt.ylabel("x");plt.xlabel("t");
plt.axvline(t1,color="r")
plt.text(t1//2,min(data),f"lw,{exp1}");plt.text(t1 + (t2//2),min(data),f"sbm,{exp2}");
